# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train_fwYjLYX.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80402 entries, 0 to 80401
# Data columns (total 6 columns):
# application_date    80402 non-null object
# segment             80402 non-null int64
# branch_id           66898 non-null float64
# state               80402 non-null object
# zone                66898 non-null object
# case_count          80402 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.7+ MB

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['branch_id', 'zone']

# %%
df['zone'].value_counts()
# Out:
# EAST       21762
# SOUTH      18538
# WEST       16926
# NORTH       8060
# CENTRAL     1612
# Name: zone, dtype: int64

# %%
df['state'].value_counts()
# Out:
# MAHARASHTRA       11322
# WEST BENGAL        7292
# GUJARAT            7292
# TAMIL NADU         6486
# UTTAR PRADESH      6486
# PUNJAB             4874
# ANDHRA PRADESH     4836
# HARYANA            4068
# ASSAM              4068
# BIHAR              3262
# KARNATAKA          3262
# ORISSA             3262
# JHARKHAND          2456
# TRIPURA            2456
# MADHYA PRADESH     1650
# KERALA             1650
# CHHATTISGARH       1650
# TELANGANA          1612
# UTTARAKHAND        1612
# DELHI               806
# Name: state, dtype: int64

# %%
df_og=df.copy()

# %%
df_og.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80402 entries, 0 to 80401
# Data columns (total 6 columns):
# application_date    80402 non-null object
# segment             80402 non-null int64
# branch_id           66898 non-null float64
# state               80402 non-null object
# zone                66898 non-null object
# case_count          80402 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.7+ MB

# %%
df_null_features=df[['branch_id','zone']]
for i in df_null_features:
      df[i] = df[i].fillna(df[i].mode()[0])

# %%
df.columns[df.isna().any()].tolist()
# Out:
# []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80402 entries, 0 to 80401
# Data columns (total 6 columns):
# application_date    80402 non-null object
# segment             80402 non-null int64
# branch_id           80402 non-null float64
# state               80402 non-null object
# zone                80402 non-null object
# case_count          80402 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.7+ MB

# %%
df['application_date']
# Out:
# 0        2017-04-01
# 1        2017-04-03
# 2        2017-04-04
# 3        2017-04-05
# 4        2017-04-07
# 5        2017-04-12
# 6        2017-04-13
# 7        2017-04-14
# 8        2017-04-15
# 9        2017-04-16
# 10       2017-04-17
# 11       2017-04-18
# 12       2017-04-19
# 13       2017-04-20
# 14       2017-04-21
# 15       2017-04-22
# 16       2017-04-23
# 17       2017-04-24
# 18       2017-04-25
# 19       2017-04-26
# 20       2017-04-27
# 21       2017-04-28
# 22       2017-04-29
# 23       2017-04-30
# 24       2017-05-01
# 25       2017-05-02
# 26       2017-05-03
# 27       2017-05-04
# 28       2017-05-05
# 29       2017-05-07
#             ...
# 80372    2019-06-24
# 80373    2019-06-25
# 80374    2019-06-26
# 80375    2019-06-27
# 80376    2019-06-28
# 80377    2019-06-29
# 80378    2019-06-30
# 80379    2019-07-01
# 80380    2019-07-02
# 80381    2019-07-03
# 80382    2019-07-04
# 80383    2019-07-05
# 80384    2019-07-06
# 80385    2019-07-07
# ...

# %%
from datetime import datetime
 
year = lambda df: datetime.strptime(df,"%Y-%m-%d").year #note this format is specific to dataset
df['application_date_year'] = df['application_date'].map(year)# eg value of purchase date will be 2017-11-05 23:30:27
##X.head() # here we can extract year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80402 entries, 0 to 80401
# Data columns (total 7 columns):
# application_date         80402 non-null object
# segment                  80402 non-null int64
# branch_id                80402 non-null float64
# state                    80402 non-null object
# zone                     80402 non-null object
# case_count               80402 non-null float64
# application_date_year    80402 non-null int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.3+ MB

# %%
df.head()
# Out:
#   application_date  segment  branch_id        state  zone  case_count  \
# 0       2017-04-01        1        1.0  WEST BENGAL  EAST        40.0
# 1       2017-04-03        1        1.0  WEST BENGAL  EAST         5.0
# 2       2017-04-04        1        1.0  WEST BENGAL  EAST         4.0
# 3       2017-04-05        1        1.0  WEST BENGAL  EAST       113.0
# 4       2017-04-07        1        1.0  WEST BENGAL  EAST        76.0
#
#    application_date_year
# 0                   2017
# 1                   2017
# 2                   2017
# 3                   2017
# 4                   2017

# %%
month = lambda df: datetime.strptime(df,"%Y-%m-%d").month #note this format is specific to dataset
df['application_date_month'] = df['application_date'].map(month)# eg value of purchase date will be 2017-11-05 23:30:27
##X.head() # here we can extract year
day = lambda df: datetime.strptime(df,"%Y-%m-%d").day #note this format is specific to dataset
df['application_date_day'] = df['application_date'].map(day)#

# %%
df.head()
# Out:
#   application_date  segment  branch_id        state  zone  case_count  \
# 0       2017-04-01        1        1.0  WEST BENGAL  EAST        40.0
# 1       2017-04-03        1        1.0  WEST BENGAL  EAST         5.0
# 2       2017-04-04        1        1.0  WEST BENGAL  EAST         4.0
# 3       2017-04-05        1        1.0  WEST BENGAL  EAST       113.0
# 4       2017-04-07        1        1.0  WEST BENGAL  EAST        76.0
#
#    application_date_year  application_date_month  application_date_day
# 0                   2017                       4                     1
# 1                   2017                       4                     3
# 2                   2017                       4                     4
# 3                   2017                       4                     5
# 4                   2017                       4                     7

# %%
df.drop(columns='application_date',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80402 entries, 0 to 80401
# Data columns (total 8 columns):
# segment                   80402 non-null int64
# branch_id                 80402 non-null float64
# state                     80402 non-null object
# zone                      80402 non-null object
# case_count                80402 non-null float64
# application_date_year     80402 non-null int64
# application_date_month    80402 non-null int64
# application_date_day      80402 non-null int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 4.9+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lablel_encoder = LabelEncoder()
df['state'] = lablel_encoder.fit_transform(df['state'])
df['zone'] = lablel_encoder.fit_transform(df['zone'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80402 entries, 0 to 80401
# Data columns (total 8 columns):
# segment                   80402 non-null int64
# branch_id                 80402 non-null float64
# state                     80402 non-null int32
# zone                      80402 non-null int32
# case_count                80402 non-null float64
# application_date_year     80402 non-null int64
# application_date_month    80402 non-null int64
# application_date_day      80402 non-null int64
# dtypes: float64(2), int32(2), int64(4)
# memory usage: 4.3 MB

# %%
Y=df['case_count']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80402 entries, 0 to 80401
# Data columns (total 7 columns):
# segment                   80402 non-null int64
# branch_id                 80402 non-null float64
# state                     80402 non-null int32
# zone                      80402 non-null int32
# application_date_year     80402 non-null int64
# application_date_month    80402 non-null int64
# application_date_day      80402 non-null int64
# dtypes: float64(1), int32(2), int64(4)
# memory usage: 3.7 MB

# %%
X=df.drop(columns=['branch_id','state','zone','case_count'])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80402 entries, 0 to 80401
# Data columns (total 4 columns):
# segment                   80402 non-null int64
# application_date_year     80402 non-null int64
# application_date_month    80402 non-null int64
# application_date_day      80402 non-null int64
# dtypes: int64(4)
# memory usage: 2.5 MB

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
#tuning the parameters
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV
parametersGrid = {"max_iter": [1, 5, 10],
                      "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
                      "l1_ratio": np.arange(0.0, 1.0, 0.1)}
eNet = ElasticNet()
grid = GridSearchCV(eNet, parametersGrid, scoring='r2', cv=10)
grid.fit(X_train, y_train)#takes time to run since fitiing all the possible combination
clf = grid.best_estimator_ # best estimator
# Out:
# C:\Users\aakash uppadhaya\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13192323645.917892, tolerance: 3349983.921794003
#   positive)
# C:\Users\aakash uppadhaya\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12867929001.764608, tolerance: 3268545.277926023
#   positive)
# C:\Users\aakash uppadhaya\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13255713019.614376, tolerance: 3369523.5916282777
#   positive)
# ...

# %%
cv_results=grid.cv_results_ #getting cv results 
scores_df = pd.DataFrame(cv_results).sort_values(by='rank_test_score')# create the ultimate dataframe f the

# %%
scores_df.head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 85       0.014681      0.001724         0.002175        0.002202        0.01
# 86       0.016506      0.002806         0.003523        0.001447        0.01
# 88       0.015494      0.003441         0.001627        0.001749        0.01
# 89       0.016971      0.003131         0.002589        0.001891        0.01
# 31       0.015477      0.001313         0.002911        0.001843       0.001
#
#    param_l1_ratio param_max_iter  \
# 85            0.8              5
# 86            0.8             10
# 88            0.9              5
# 89            0.9             10
# 31              0              5
#
#                                               params  split0_test_score  \
# 85   {'alpha': 0.01, 'l1_ratio': 0.8, 'max_iter': 5}           0.212623
# 86  {'alpha': 0.01, 'l1_ratio': 0.8, 'max_iter': 10}           0.212624
# 88   {'alpha': 0.01, 'l1_ratio': 0.9, 'max_iter': 5}           0.212646
# ...

# %%
from sklearn.metrics import SCORERS
print(SCORERS.keys())
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'accuracy', 'roc_auc', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'brier_score_loss', 'adjusted_rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %%
l=[]
l=grid.predict(X_test)

# %%
l
# Out:
# array([878.59807451, 116.33639076,   6.49269596, ...,  44.81312217,
#         82.38148251, 852.32442339])

# %%
df_test=pd.read_csv('test_1eLl9Yf.csv')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 3 columns):
# id                  180 non-null int64
# application_date    180 non-null object
# segment             180 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 4.3+ KB

# %%
from datetime import datetime
 
year = lambda df_test: datetime.strptime(df_test,"%Y-%m-%d").year #note this format is specific to dataset
df_test['application_date_year'] = df_test['application_date'].map(year)# eg value of purchase date will be 2017-11-05 23:30:27
##X.head() # here we can extract year
month = lambda df_test: datetime.strptime(df_test,"%Y-%m-%d").month #note this format is specific to dataset
df_test['application_date_month'] = df_test['application_date'].map(month)# eg value of purchase date will be 2017-11-05 23:30:27
##X.head() # here we can extract year
day = lambda df_test: datetime.strptime(df_test,"%Y-%m-%d").day #note this format is specific to dataset
df_test['application_date_day'] = df_test['application_date'].map(day)#
df_test.drop(columns=['id','application_date'],inplace=True)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 4 columns):
# segment                   180 non-null int64
# application_date_year     180 non-null int64
# application_date_month    180 non-null int64
# application_date_day      180 non-null int64
# dtypes: int64(4)
# memory usage: 5.7 KB

# %%
df_test['case_count']=grid.predict(df_test)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 5 columns):
# segment                   180 non-null int64
# application_date_year     180 non-null int64
# application_date_month    180 non-null int64
# application_date_day      180 non-null int64
# case_count                180 non-null float64
# dtypes: float64(1), int64(4)
# memory usage: 7.1 KB

# %%
export_csv=df_test.to_csv('first_cut.csv')

# %%
df_test['case_count']
# Out:
# 0        62.325473
# 1        66.958439
# 2        71.591405
# 3        76.224371
# 4        80.857337
# 5        85.490303
# 6        90.123269
# 7        94.756235
# 8        99.389201
# 9       104.022168
# 10      108.655134
# 11      113.288100
# 12      117.921066
# 13      122.554032
# 14      127.186998
# 15      131.819964
# 16      136.452930
# 17      141.085896
# 18      145.718862
# 19      150.351829
# 20      154.984795
# 21      159.617761
# 22      164.250727
# 23      168.883693
# 24      173.516659
# 25      178.149625
# 26       45.348018
# 27       49.980985
# 28       54.613951
# 29       59.246917
#           ...
# 150    1075.332487
# 151    1079.965453
# 152    1084.598419
# 153    1089.231385
# 154    1093.864351
# 155    1098.497318
# 156     970.328677
# 157     974.961643
# 158     979.594609
# 159     984.227575
# 160     988.860541
# 161     993.493507
# 162     998.126474
# 163    1002.759440
# 164    1007.392406
# 165    1012.025372
# ...
